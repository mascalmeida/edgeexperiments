# %%
import pandas as pd

# %%
dt_worst = pd.read_csv('Worst_fit_migration.csv')
dt_qlearning = pd.read_csv('Qlearning_migration.csv')
dt_actor = pd.read_csv('Probabilistic_actor_critic_migration.csv')
dt_mab = pd.read_csv('MAB_migration.csv')
dt_gcn = pd.read_csv('GCN_Q_learning_migration.csv')

# %%
dt_gcn#['Power Consumption'].sum()#/6006
# Out:
#             Object  Time Step  Instance ID  Power Consumption
# 0     EdgeServer_1          0            1         165.996000
# 1     EdgeServer_2          0            2         165.996000
# 2     EdgeServer_3          0            3          66.991400
# 3     EdgeServer_4          0            4          66.991400
# 4     EdgeServer_5          0            5          74.508333
# ...            ...        ...          ...                ...
# 6001  EdgeServer_2       1000            2         165.996000
# 6002  EdgeServer_3       1000            3          66.991400
# 6003  EdgeServer_4       1000            4          66.991400
# 6004  EdgeServer_5       1000            5          74.508333
# 6005  EdgeServer_6       1000            6          97.325000
#
# [6006 rows x 4 columns]
